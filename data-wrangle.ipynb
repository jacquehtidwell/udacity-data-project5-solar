# %%
import requests
import numpy as np
import pandas as pd
import os

import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import cm as cm

import seaborn as sns 
import datetime
from datetime import datetime

# %% [markdown]
# # 1 Data Gathering - SolarView
#
# https://github.com/social-energy-atlas/solarview-data
#
# ## Installations

# %%
installs = pd.read_csv('cleaning/clean_data/installs_clean.csv', encoding='utf-8')
installs.head(5)
# Out:
#   sea_install_id original_db    zip   fips         town    state  \
# 0  southface_S53   Southface  31408  13051  Garden City  Georgia
# 1  southface_S55   Southface  30601  13059       Athens  Georgia
# 2  southface_S59   Southface  30030  13089      Decatur  Georgia
# 3  southface_S52   Southface  30005  13121   Alpharetta  Georgia
# 4  southface_S49   Southface  30281  13151  Stockbridge  Georgia
#
#        system_type       sector install_date                utility  \
# 0  Solar Hot Water  Residential   2008-01-01  Georgia Power Company
# 1  Solar Hot Water  Residential   2008-01-01  Georgia Power Company
# 2  Solar Hot Water  Residential   2008-01-01  Georgia Power Company
# 3  Solar Hot Water  Residential   2008-01-01             Sawnee EMC
# 4  Solar Hot Water  Residential   2008-01-01  Georgia Power Company
#
#          lat       long
# 0  32.119290 -81.151748
# 1  33.976445 -83.368683
# 2  33.767515 -84.308954
# 3  34.070288 -84.202196
# 4  33.501071 -84.257491

# %%
installs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2117 entries, 0 to 2116
# Data columns (total 12 columns):
# sea_install_id    2116 non-null object
# original_db       2117 non-null object
# zip               2117 non-null object
# fips              2117 non-null object
# town              2117 non-null object
# state             2116 non-null object
# system_type       2116 non-null object
# sector            2116 non-null object
# install_date      2115 non-null object
# utility           600 non-null object
# lat               2115 non-null float64
# long              2115 non-null float64
# dtypes: float64(2), object(10)
# memory usage: 198.6+ KB

# %%
installs['install_date'] = pd.to_datetime(installs['install_date'])

# %%
installs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2117 entries, 0 to 2116
# Data columns (total 12 columns):
# sea_install_id    2116 non-null object
# original_db       2117 non-null object
# zip               2117 non-null object
# fips              2117 non-null object
# town              2117 non-null object
# state             2116 non-null object
# system_type       2116 non-null object
# sector            2116 non-null object
# install_date      2115 non-null datetime64[ns]
# utility           600 non-null object
# lat               2115 non-null float64
# long              2115 non-null float64
# dtypes: datetime64[ns](1), float64(2), object(9)
# memory usage: 198.6+ KB

# %%
installs.isnull().sum()
# Out:
# sea_install_id       1
# original_db          0
# zip                  0
# fips                 0
# town                 0
# state                1
# system_type          1
# sector               1
# install_date         2
# utility           1517
# lat                  2
# long                 2
# dtype: int64

# %%
installs[installs['sea_install_id'].isnull()]
# Out:
#      sea_install_id original_db             zip         fips        town  \
# 1514            NaN     Georgia  Solar Electric  Residential  2014-12-01
#
#                       state system_type     sector install_date utility  lat  \
# 1514  Georgia Power Company   31.957942  -81.32203          NaT     NaN  NaN
#
#       long
# 1514   NaN

# %%
installs.drop([1514], inplace=True)

# %%
installs[installs['state'].isnull()]
# Out:
#        sea_install_id original_db    zip   fips           town state  \
# 1513  southface_SSM10   Southface  31324  13029  Richmond Hill   NaN
#
#      system_type sector install_date utility  lat  long
# 1513         NaN    NaN          NaT     NaN  NaN   NaN

# %%
installs.drop([1513], inplace=True)

# %%
installs.isnull().sum()
# Out:
# sea_install_id       0
# original_db          0
# zip                  0
# fips                 0
# town                 0
# state                0
# system_type          0
# sector               0
# install_date         0
# utility           1515
# lat                  0
# long                 0
# dtype: int64

# %%
installs[installs['utility'].isnull()]
# Out:
#              sea_install_id original_db    zip   fips      town    state  \
# 27           southface_SF24   Southface  30318  13121   Atlanta  Georgia
# 28           southface_SF25   Southface  30318  13121   Atlanta  Georgia
# 29           southface_SF33   Southface  30240  13285  LaGrange  Georgia
# 30           southface_SF20   Southface  30064  13067  Marietta  Georgia
# 31           southface_SF96   Southface  31774  13155    Ocilla  Georgia
# ...                     ...         ...    ...    ...       ...      ...
# 2112  southface_RS17-1-0003   Southface  30339  13067   Atlanta  Georgia
# 2113        southface_CS113   Southface  30306  13121   Atlanta  Georgia
# 2114         southface_AS10   Southface  30268  13077  Palmetto  Georgia
# 2115        southface_SF161   Southface  30810  13125    Gibson  Georgia
# 2116       southface_AES118   Southface  30017  13135   Grayson  Georgia
#
#           system_type           sector install_date utility        lat  \
# ...

# %%
installs["utility"].fillna("Unknown", inplace = True)

# %%
installs[installs['utility'].isnull()]
# Out:
# Empty DataFrame
# Columns: [sea_install_id, original_db, zip, fips, town, state, system_type, sector, install_date, utility, lat, long]
# Index: []

# %%
installs.isnull().sum()
# Out:
# sea_install_id    0
# original_db       0
# zip               0
# fips              0
# town              0
# state             0
# system_type       0
# sector            0
# install_date      0
# utility           0
# lat               0
# long              0
# dtype: int64

# %%
installs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2115 entries, 0 to 2116
# Data columns (total 12 columns):
# sea_install_id    2115 non-null object
# original_db       2115 non-null object
# zip               2115 non-null object
# fips              2115 non-null object
# town              2115 non-null object
# state             2115 non-null object
# system_type       2115 non-null object
# sector            2115 non-null object
# install_date      2115 non-null datetime64[ns]
# utility           2115 non-null object
# lat               2115 non-null float64
# long              2115 non-null float64
# dtypes: datetime64[ns](1), float64(2), object(9)
# memory usage: 214.8+ KB

# %% [markdown]
# ## Bring in County Name
