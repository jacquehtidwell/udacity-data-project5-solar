# %%
import numpy as np
import pandas as pd
import os

import datetime
from datetime import datetime

# %% [markdown]
# # 1 Data Gathering - SolarView
#
# https://github.com/social-energy-atlas/solarview-data
#
# ## 1.1 Installations

# %%
installs = pd.read_csv('data/sea-solar-installations.csv', encoding='utf-8')
installs.head(5)
# Out:
#   sea-install-id oiriginal-db      zip   fips         town    state  \
# 0  southface_S53    Southface  31408.0  13051  Garden City  Georgia
# 1  southface_S55    Southface  30601.0  13059       Athens  Georgia
# 2  southface_S59    Southface  30030.0  13089      Decatur  Georgia
# 3  southface_S52    Southface  30005.0  13121   Alpharetta  Georgia
# 4  southface_S49    Southface  30281.0  13151  Stockbridge  Georgia
#
#        system-type       sector install-date                utility  \
# 0  Solar Hot Water  Residential   01/01/2008  Georgia Power Company
# 1  Solar Hot Water  Residential   01/01/2008  Georgia Power Company
# 2  Solar Hot Water  Residential   01/01/2008  Georgia Power Company
# 3  Solar Hot Water  Residential   01/01/2008             Sawnee EMC
# 4  Solar Hot Water  Residential   01/01/2008  Georgia Power Company
#
#    federal-cong-dist  state-senate-dist  state-house-dist        lat  \
# 0                1.0                2.0             162.0  32.119290
# 1               10.0               46.0             118.0  33.976445
# 2                5.0               42.0              83.0  33.767515
# 3                6.0               48.0              25.0  34.070288
# 4               13.0               10.0             111.0  33.501071
#
#         long
# 0 -81.151748
# 1 -83.368683
# 2 -84.308954
# 3 -84.202196
# 4 -84.257491

# %%
installs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2139 entries, 0 to 2138
# Data columns (total 15 columns):
# sea-install-id       2139 non-null object
# oiriginal-db         2139 non-null object
# zip                  2138 non-null float64
# fips                 2139 non-null int64
# town                 2099 non-null object
# state                2139 non-null object
# system-type          2139 non-null object
# sector               2139 non-null object
# install-date         2139 non-null object
# utility              601 non-null object
# federal-cong-dist    765 non-null float64
# state-senate-dist    765 non-null float64
# state-house-dist     765 non-null float64
# lat                  2117 non-null float64
# long                 2117 non-null float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 250.8+ KB

# %% [markdown]
# # 2 Data Assessment
# ## 2.1 Installations

# %%
installs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2139 entries, 0 to 2138
# Data columns (total 15 columns):
# sea-install-id       2139 non-null object
# oiriginal-db         2139 non-null object
# zip                  2138 non-null float64
# fips                 2139 non-null int64
# town                 2099 non-null object
# state                2139 non-null object
# system-type          2139 non-null object
# sector               2139 non-null object
# install-date         2139 non-null object
# utility              601 non-null object
# federal-cong-dist    765 non-null float64
# state-senate-dist    765 non-null float64
# state-house-dist     765 non-null float64
# lat                  2117 non-null float64
# long                 2117 non-null float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 250.8+ KB

# %% [markdown]
# - install-date is not in datetime format
# - fips is not a string
# - error in spelling of original database column

# %%
installs.sample(5)
# Out:
#         sea-install-id oiriginal-db      zip   fips      town    state  \
# 1557    southface_UR10    Southface  30477.0  13163    Wadley  Georgia
# 2135   southface_CS113    Southface  30306.0  13121   Atlanta  Georgia
# 1080    southface_M450    Southface  30067.0  13067  Marietta  Georgia
# 1704    southface_CS15    Southface  31709.0  13261  Americus  Georgia
# 1885  southface_AES056    Southface  30606.0  13059    Athens  Georgia
#
#          system-type           sector install-date                utility  \
# 1557  Solar Electric          Utility   12/16/2014  Georgia Power Company
# 2135  Solar Electric      Residential   08/30/2017                    NaN
# 1080  Solar Electric  Non-Residential   02/27/2012                    NaN
# 1704  Solar Electric  Non-Residential   08/01/2015                    NaN
# 1885  Solar Electric      Residential   08/12/2016                    NaN
#
#       federal-cong-dist  state-senate-dist  state-house-dist        lat  \
# 1557               10.0               23.0             128.0  32.884425
# 2135                NaN                NaN               NaN  33.778986
# 1080                6.0               33.0              42.0  33.949305
# 1704                NaN                NaN               NaN  32.072874
# 1885                NaN                NaN               NaN  33.932947
#
#            long
# 1557 -82.408950
# 2135 -84.354015
# 1080 -84.499942
# 1704 -84.227576
# 1885 -83.387305

# %%
installs.shape
# Out:
# (2139, 15)

# %%
installs.isnull().sum()
# Out:
# sea-install-id          0
# oiriginal-db            0
# zip                     1
# fips                    0
# town                   40
# state                   0
# system-type             0
# sector                  0
# install-date            0
# utility              1538
# federal-cong-dist    1374
# state-senate-dist    1374
# state-house-dist     1374
# lat                    22
# long                   22
# dtype: int64

# %%
installs.duplicated().sum()
# Out:
# 1

# %% [markdown]
# - NaN present in zip, town, lat, utility, federal-cong-dist, state-senate-dist, state-house-dist, lat, and long.
# - Can't check for duplicated id because of column name.
# - zip is an integer and not a string

# %% [markdown]
# # 3 Data Cleaning
#
# ## 3.1 Copy All Dataframes
#
# ### 3.1.1 Define
# Copy all dataframes for cleaning purposes.
#
# #### 3.1.1.2 Code

# %%
installs_clean = installs.copy()

# %% [markdown]
# #### 3.1.1.3 Test

# %%
installs_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2139 entries, 0 to 2138
# Data columns (total 15 columns):
# sea-install-id       2139 non-null object
# oiriginal-db         2139 non-null object
# zip                  2138 non-null float64
# fips                 2139 non-null int64
# town                 2099 non-null object
# state                2139 non-null object
# system-type          2139 non-null object
# sector               2139 non-null object
# install-date         2139 non-null object
# utility              601 non-null object
# federal-cong-dist    765 non-null float64
# state-senate-dist    765 non-null float64
# state-house-dist     765 non-null float64
# lat                  2117 non-null float64
# long                 2117 non-null float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 250.8+ KB

# %% [markdown]
# ## 3.2 Installations
#
# Installations
#
# - install-date is not in datetime format - DONE
# - fips is not a string
# - zip is an integer and not a string
# - Drop congressional districts, as not useful.
# - NaN present in zip, town, lat, utility, federal-cong-dist, state-senate-dist, state-house-dist, lat, and long.
# - Can't check for duplicated id because of column name.
#
#
# ### 3.2.1 Rename Columns
# #### 3.2.1.1 Define

# %% [markdown]
# ## 3.2 Column Naming
# ### 3.2.1 Installations
# #### 3.2.1.1 Define
# Rename all columns so that hyphens are replaced with underscores so that future codes can be run successfully, as well as correcting any spelling errors.
#
# #### 3.2.1.2 Code

# %%
installs_clean = installs_clean.rename(columns={"sea-install-id": "sea_install_id", 
                                                "oiriginal-db": "original_db", 
                                                "system-type": "system_type", 
                                                "install-date": "install_date", 
                                                "federal-cong-dist": "fed_congressional_district", 
                                                "state-senate-dist": "state_senate_district", 
                                                "state-house-dist": "state_house_district"})

# %% [markdown]
# #### 3.2.1.3 Test

# %%
installs_clean.head()
# Out:
#   sea_install_id original_db      zip   fips         town    state  \
# 0  southface_S53   Southface  31408.0  13051  Garden City  Georgia
# 1  southface_S55   Southface  30601.0  13059       Athens  Georgia
# 2  southface_S59   Southface  30030.0  13089      Decatur  Georgia
# 3  southface_S52   Southface  30005.0  13121   Alpharetta  Georgia
# 4  southface_S49   Southface  30281.0  13151  Stockbridge  Georgia
#
#        system_type       sector install_date                utility  \
# 0  Solar Hot Water  Residential   01/01/2008  Georgia Power Company
# 1  Solar Hot Water  Residential   01/01/2008  Georgia Power Company
# 2  Solar Hot Water  Residential   01/01/2008  Georgia Power Company
# 3  Solar Hot Water  Residential   01/01/2008             Sawnee EMC
# 4  Solar Hot Water  Residential   01/01/2008  Georgia Power Company
#
#    fed_congressional_district  state_senate_district  state_house_district  \
# 0                         1.0                    2.0                 162.0
# 1                        10.0                   46.0                 118.0
# 2                         5.0                   42.0                  83.0
# 3                         6.0                   48.0                  25.0
# 4                        13.0                   10.0                 111.0
#
#          lat       long
# 0  32.119290 -81.151748
# 1  33.976445 -83.368683
# 2  33.767515 -84.308954
# 3  34.070288 -84.202196
# 4  33.501071 -84.257491

# %% [markdown]
# ### 3.2.2 Convert install_date to datetime format
# #### 3.2.2.1 Define
# The install_date column should be in datetime format. Drop any unknown dates and convert those values to datetime.
#
# #### 3.2.2.2 Code

# %%
installs_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2139 entries, 0 to 2138
# Data columns (total 15 columns):
# sea_install_id                2139 non-null object
# original_db                   2139 non-null object
# zip                           2138 non-null float64
# fips                          2139 non-null int64
# town                          2099 non-null object
# state                         2139 non-null object
# system_type                   2139 non-null object
# sector                        2139 non-null object
# install_date                  2139 non-null object
# utility                       601 non-null object
# fed_congressional_district    765 non-null float64
# state_senate_district         765 non-null float64
# state_house_district          765 non-null float64
# lat                           2117 non-null float64
# long                          2117 non-null float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 250.8+ KB

# %%
installs_clean['install_date'] = pd.to_datetime(installs_clean['install_date'])

# %% [markdown]
# #### 3.2.2.3 Test

# %%
installs_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2139 entries, 0 to 2138
# Data columns (total 15 columns):
# sea_install_id                2139 non-null object
# original_db                   2139 non-null object
# zip                           2138 non-null float64
# fips                          2139 non-null int64
# town                          2099 non-null object
# state                         2139 non-null object
# system_type                   2139 non-null object
# sector                        2139 non-null object
# install_date                  2139 non-null datetime64[ns]
# utility                       601 non-null object
# fed_congressional_district    765 non-null float64
# state_senate_district         765 non-null float64
# state_house_district          765 non-null float64
# lat                           2117 non-null float64
# long                          2117 non-null float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(7)
# memory usage: 250.8+ KB

# %% [markdown]
# ### 3.2.3 Convert fips, zip, and congressional district columns to strings
# #### 3.2.3.1 Define
# Convert the fips, zip, fed_congressional_district, state_senate_district, and state_house_district columns to string format all columns.
#
# #### 3.2.3.2 Code

# %%
print(installs_clean[installs_clean['zip'].isnull()])
# Out:
#        sea_install_id original_db  zip   fips town    state     system_type  \
# 1833  southface_SF137   Southface  NaN  13053  NaN  Georgia  Solar Electric
#
#        sector install_date utility  fed_congressional_district  \
# 1833  Utility   2016-06-01     NaN                         NaN
#
#       state_senate_district  state_house_district        lat       long
# 1833                    NaN                   NaN  32.318057 -84.972077

# %%
installs_clean.drop([1833], inplace=True)
installs_clean['zip'] = installs_clean['zip'].round(0).astype(int)
installs_clean['zip'] = installs_clean['zip'].astype(str)
installs_clean['fips'] = installs_clean['fips'].astype(str)

# %% [markdown]
# #### 3.2.3.3 Test

# %%
installs_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2138 entries, 0 to 2138
# Data columns (total 15 columns):
# sea_install_id                2138 non-null object
# original_db                   2138 non-null object
# zip                           2138 non-null object
# fips                          2138 non-null object
# town                          2099 non-null object
# state                         2138 non-null object
# system_type                   2138 non-null object
# sector                        2138 non-null object
# install_date                  2138 non-null datetime64[ns]
# utility                       601 non-null object
# fed_congressional_district    765 non-null float64
# state_senate_district         765 non-null float64
# state_house_district          765 non-null float64
# lat                           2116 non-null float64
# long                          2116 non-null float64
# dtypes: datetime64[ns](1), float64(5), object(9)
# memory usage: 267.2+ KB

# %%
installs_clean.head(5)
# Out:
#   sea_install_id original_db    zip   fips         town    state  \
# 0  southface_S53   Southface  31408  13051  Garden City  Georgia
# 1  southface_S55   Southface  30601  13059       Athens  Georgia
# 2  southface_S59   Southface  30030  13089      Decatur  Georgia
# 3  southface_S52   Southface  30005  13121   Alpharetta  Georgia
# 4  southface_S49   Southface  30281  13151  Stockbridge  Georgia
#
#        system_type       sector install_date                utility  \
# 0  Solar Hot Water  Residential   2008-01-01  Georgia Power Company
# 1  Solar Hot Water  Residential   2008-01-01  Georgia Power Company
# 2  Solar Hot Water  Residential   2008-01-01  Georgia Power Company
# 3  Solar Hot Water  Residential   2008-01-01             Sawnee EMC
# 4  Solar Hot Water  Residential   2008-01-01  Georgia Power Company
#
#    fed_congressional_district  state_senate_district  state_house_district  \
# 0                         1.0                    2.0                 162.0
# 1                        10.0                   46.0                 118.0
# 2                         5.0                   42.0                  83.0
# 3                         6.0                   48.0                  25.0
# 4                        13.0                   10.0                 111.0
#
#          lat       long
# 0  32.119290 -81.151748
# 1  33.976445 -83.368683
# 2  33.767515 -84.308954
# 3  34.070288 -84.202196
# 4  33.501071 -84.257491

# %% [markdown]
# ### 3.2.4 Investigate town NaN values
# #### 3.2.4.1 Define
# Query the dataset and investigate NaN values for the town column to see if data can be retrieved to complete. Otherwise, remove observations from the dataset.
#
# #### 3.2.4.2 Code

# %%
installs_clean[installs_clean['town'].isnull()]
# Out:
#            sea_install_id original_db    zip   fips town    state  \
# 36       southface_SF131a   Southface  30305  13121  NaN  Georgia
# 43       southface_SF131b   Southface  30305  13121  NaN  Georgia
# 684       southface_SF126   Southface  30188  13067  NaN  Georgia
# 885        southface_UR01   Southface  31906  40101  NaN  Georgia
# 1349      southface_M1053   Southface  30054  13297  NaN  Georgia
# 1353      southface_M1055   Southface  30040  13117  NaN  Georgia
# 1370      southface_M1051   Southface  30143  13227  NaN  Georgia
# 1382      southface_M1056   Southface  31406  13051  NaN  Georgia
# 1415      southface_SF125   Southface  31018  13303  NaN  Georgia
# 1451      southface_M1054   Southface  30269  13113  NaN  Georgia
# 1472  southface_GPC-10472   Southface  30439  13043  NaN  Georgia
# 1473  southface_GPC-10265   Southface  31006  13269  NaN  Georgia
# 1483      southface_SF124   Southface  31409  13051  NaN  Georgia
# 1490      southface_SF127   Southface  30230  13199  NaN  Georgia
# 1493      southface_SSW19   Southface  30650  13211  NaN  Georgia
# 1497      southface_SSW20   Southface  30044  13135  NaN  Georgia
# 1506      southface_SSW22   Southface  30056  13211  NaN  Georgia
# 1507  southface_GPC-10133   Southface  30120  13015  NaN  Georgia
# 1508       southface_HS56   Southface  30222  13199  NaN  Georgia
# 1509      southface_SSW23   Southface  30533  13187  NaN  Georgia
# 1517  southface_GPC-10190   Southface  30805  13033  NaN  Georgia
# 1518  southface_GPC-10140   Southface  30553  13119  NaN  Georgia
# 1585  32.388299 -83.142471
# 1587  33.766010 -84.295146
# 1606  32.256800 -83.744800
# 1607  34.260040 -85.301251
# 1611  33.924649 -84.351386
# 1991  32.561115 -84.276448

# %%
print(installs_clean['zip'][36])
print(installs_clean['zip'][43])
print(installs_clean['zip'][684])
print(installs_clean['zip'][885])
print(installs_clean['zip'][1349])
# Out:
# 30305
# 30305
# 30188
# 31906
# 30054

# %%
installs_clean.at[36, 'town'] = 'Atlanta'
installs_clean.at[43, 'town'] = 'Atlanta'
installs_clean.at[684, 'town'] = 'Woodstock'
installs_clean.at[885, 'town'] = 'Columbus'
installs_clean.at[1349, 'town'] = 'Oxford'

# %%
print(installs_clean['zip'][1353])
print(installs_clean['zip'][1370])
print(installs_clean['zip'][1382])
print(installs_clean['zip'][1415])
print(installs_clean['zip'][1451])
# Out:
# 30040
# 30143
# 31406
# 31018
# 30269

# %%
installs_clean.at[1382, 'town'] = 'Savannah'
installs_clean.at[1451, 'town'] = 'Peachtree City'
installs_clean.at[1353, 'town'] = 'Cumming'
installs_clean.at[1370, 'town'] = 'Jasper'
installs_clean.at[1415, 'town'] = 'Davisboro'

# %%
print(installs_clean['zip'][1472])
print(installs_clean['zip'][1473])
print(installs_clean['zip'][1483])
print(installs_clean['zip'][1490])
print(installs_clean['zip'][1493])
# Out:
# 30439
# 31006
# 31409
# 30230
# 30650

# %%
installs_clean.at[1472, 'town'] = 'Metter'
installs_clean.at[1473, 'town'] = 'Butler'
installs_clean.at[1483, 'town'] = 'Savannah'
installs_clean.at[1490, 'town'] = 'Hogansville'
installs_clean.at[1493, 'town'] = 'Madison'

# %%
print(installs_clean['zip'][1497])
print(installs_clean['zip'][1506])
print(installs_clean['zip'][1507])
print(installs_clean['zip'][1508])
print(installs_clean['zip'][1509])
# Out:
# 30044
# 30056
# 30120
# 30222
# 30533

# %%
installs_clean.at[1497, 'town'] = 'Lawrenceville'
installs_clean.at[1506, 'town'] = 'Newborn'
installs_clean.at[1507, 'town'] = 'Cartersville'
installs_clean.at[1508, 'town'] = 'Greenville'
installs_clean.at[1509, 'town'] = 'Dahlonega'

# %%
print(installs_clean['zip'][1517])
print(installs_clean['zip'][1518])
print(installs_clean['zip'][1529])
print(installs_clean['zip'][1551])
print(installs_clean['zip'][1552])
# Out:
# 30805
# 30553
# 30625
# 30030
# 30417

# %%
installs_clean.at[1517, 'town'] = 'Augusta'
installs_clean.at[1518, 'town'] = 'Lavonia'
installs_clean.at[1529, 'town'] = 'Buckhead'
installs_clean.at[1551, 'town'] = 'Decatur'
installs_clean.at[1552, 'town'] = 'Claxton'

# %%
print(installs_clean['zip'][1558])
print(installs_clean['zip'][1561])
print(installs_clean['zip'][1562])
print(installs_clean['zip'][1565])
print(installs_clean['zip'][1577])
# Out:
# 30030
# 30030
# 31525
# 30549
# 30124

# %%
installs_clean.at[1558, 'town'] = 'Decatur'
installs_clean.at[1561, 'town'] = 'Decatur'
installs_clean.at[1562, 'town'] = 'Brunswick'
installs_clean.at[1565, 'town'] = 'Jefferson'
installs_clean.at[1577, 'town'] = 'Cave Spring'

# %%
print(installs_clean['zip'][1581])
print(installs_clean['zip'][1583])
print(installs_clean['zip'][1584])
print(installs_clean['zip'][1585])
print(installs_clean['zip'][1587])
# Out:
# 30909
# 39845
# 31796
# 31012
# 30030

# %%
installs_clean.at[1581, 'town'] = 'Augusta'
installs_clean.at[1583, 'town'] = 'Donalsonville'
installs_clean.at[1584, 'town'] = 'Acorn Pond'
installs_clean.at[1585, 'town'] = 'Chester'
installs_clean.at[1587, 'town'] = 'Decatur'

# %%
print(installs_clean['zip'][1606])
print(installs_clean['zip'][1607])
print(installs_clean['zip'][1611])
print(installs_clean['zip'][1991])
# Out:
# 31091
# 30165
# 30328
# 31006

# %%
installs_clean.at[1606, 'town'] = 'Unadilla'
installs_clean.at[1607, 'town'] = 'Rome'
installs_clean.at[1611, 'town'] = 'Sandy Springs'
installs_clean.at[1991, 'town'] = 'Butler'

# %% [markdown]
# #### 3.2.4.3 Test

# %%
print(installs_clean[installs_clean['town'].isnull()])
# Out:
# Empty DataFrame
# Columns: [sea_install_id, original_db, zip, fips, town, state, system_type, sector, install_date, utility, fed_congressional_district, state_senate_district, state_house_district, lat, long]
# Index: []

# %% [markdown]
# ### 3.2.5 Remove all observations with no latitude or longitude
# #### 3.2.5.1 Define
# Query the dataset and remove all NaN lat/long observations.
#
# #### 3.2.5.2 Code

# %%
installs_clean[installs_clean['lat'].isnull()]
# Out:
#      sea_install_id original_db    zip   fips            town    state  \
# 29       nrel_NREL1        NREL  31405  13051        Savannah  Georgia
# 31       nrel_NREL2        NREL  30308  13121         Atlanta  Georgia
# 90       nrel_NREL3        NREL  30022  13121      Alpharetta  Georgia
# 217      nrel_NREL4        NREL  30305  13121         Atlanta  Georgia
# 284      nrel_NREL5        NREL  31321  13029        Pembroke  Georgia
# 290      nrel_NREL6        NREL  30541  13111         Epworth  Georgia
# 339      nrel_NREL7        NREL  30513  13111      Blue Ridge  Georgia
# 341      nrel_NREL8        NREL  30269  13113  Peachtree City  Georgia
# 358      nrel_NREL9        NREL  30055  13159       Mansfield  Georgia
# 388     nrel_NREL10        NREL  30721  13313          Dalton  Georgia
# 409     nrel_NREL11        NREL  30004  13117      Alpharetta  Georgia
# 455     nrel_NREL12        NREL  30522  13123      Cherry Log  Georgia
# 549     nrel_NREL13        NREL  30725  13295      Flintstone  Georgia
# 577     nrel_NREL14        NREL  30172  13115         Shannon  Georgia
# 583     nrel_NREL15        NREL  30004  13117      Alpharetta  Georgia
# 762     nrel_NREL16        NREL  30004  13117      Alpharetta  Georgia
# 763     nrel_NREL17        NREL  31021  13175          Dublin  Georgia
# 1001    nrel_NREL18        NREL  31206  13021           Macon  Georgia
# 1007    nrel_NREL19        NREL  30906  13245         Augusta  Georgia
# 1260    nrel_NREL20        NREL  30093  13135        Norcross  Georgia
# 1337    nrel_NREL21        NREL  30622  13059          Bogart  Georgia
# 1644    nrel_NREL22        NREL  30458  13031      Statesboro  Georgia
#
#          system_type           sector install_date utility  \
# 29    Solar Electric      Residential   1997-10-13     NaN
# 31    Solar Electric  Non-Residential   2002-01-01     NaN
# 90    Solar Electric      Residential   2008-09-02     NaN
# 217   Solar Electric      Residential   2009-07-03     NaN
# 284   Solar Electric  Non-Residential   2009-09-25     NaN
# 290   Solar Electric          Unknown   2009-09-30     NaN
# 339   Solar Electric          Unknown   2009-12-08     NaN
# 341   Solar Electric  Non-Residential   2009-12-15     NaN
# 358   Solar Electric      Residential   2010-01-03     NaN
# 388   Solar Electric          Unknown   2010-01-08     NaN
# 409   Solar Electric  Non-Residential   2010-01-25     NaN
# 455   Solar Electric          Unknown   2010-03-05     NaN
# 549   Solar Electric          Unknown   2010-06-28     NaN
# 577   Solar Electric          Unknown   2010-07-28     NaN
# 583   Solar Electric      Residential   2010-08-06     NaN
# 762   Solar Electric  Non-Residential   2011-03-01     NaN
# 763   Solar Electric  Non-Residential   2011-03-01     NaN
# 1001  Solar Electric  Non-Residential   2011-12-14     NaN
# 1007  Solar Electric  Non-Residential   2011-12-15     NaN
# 1260  Solar Electric  Non-Residential   2012-09-05     NaN
# 1337  Solar Electric  Non-Residential   2013-01-14     NaN
# 1644  Solar Electric      Residential   2015-05-02     NaN
#
#       fed_congressional_district  state_senate_district  state_house_district  \
# 29                           NaN                    NaN                   NaN
# 31                           NaN                    NaN                   NaN
# 90                           NaN                    NaN                   NaN
# 217                          NaN                    NaN                   NaN
# 284                          NaN                    NaN                   NaN
# 290                          NaN                    NaN                   NaN
# 339                          NaN                    NaN                   NaN
# 341                          NaN                    NaN                   NaN
# 358                          NaN                    NaN                   NaN
# 388                          NaN                    NaN                   NaN
# 409                          NaN                    NaN                   NaN
# 455                          NaN                    NaN                   NaN
# 549                          NaN                    NaN                   NaN
# 577                          NaN                    NaN                   NaN
# 583                          NaN                    NaN                   NaN
# 762                          NaN                    NaN                   NaN
# 763                          NaN                    NaN                   NaN
# 1001                         NaN                    NaN                   NaN
# 1007                         NaN                    NaN                   NaN
# 1260                         NaN                    NaN                   NaN
# 1337                         NaN                    NaN                   NaN
# 1644                         NaN                    NaN                   NaN
#
#       lat  long
# 29    NaN   NaN
# 31    NaN   NaN
# 90    NaN   NaN
# 217   NaN   NaN
# 284   NaN   NaN
# 290   NaN   NaN
# 339   NaN   NaN
# 341   NaN   NaN
# 358   NaN   NaN
# 388   NaN   NaN
# 409   NaN   NaN
# 455   NaN   NaN
# 549   NaN   NaN
# 577   NaN   NaN
# 583   NaN   NaN
# 762   NaN   NaN
# 763   NaN   NaN
# 1001  NaN   NaN
# 1007  NaN   NaN
# 1260  NaN   NaN
# 1337  NaN   NaN
# 1644  NaN   NaN

# %%
installs_clean[installs_clean['lat'].isnull()].shape
# Out:
# (22, 15)

# %%
installs_clean.drop([29,31,90,217,284,290,339,341,358,388,409,455,549,577,583,762,763,1001,1007,1260,1337,1644], inplace=True)

# %% [markdown]
# #### 3.2.5.2 Test

# %%
installs_clean[installs_clean['lat'].isnull()]
# Out:
# Empty DataFrame
# Columns: [sea_install_id, original_db, zip, fips, town, state, system_type, sector, install_date, utility, fed_congressional_district, state_senate_district, state_house_district, lat, long]
# Index: []

# %%
installs_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2116 entries, 0 to 2138
# Data columns (total 15 columns):
# sea_install_id                2116 non-null object
# original_db                   2116 non-null object
# zip                           2116 non-null object
# fips                          2116 non-null object
# town                          2116 non-null object
# state                         2116 non-null object
# system_type                   2116 non-null object
# sector                        2116 non-null object
# install_date                  2116 non-null datetime64[ns]
# utility                       601 non-null object
# fed_congressional_district    765 non-null float64
# state_senate_district         765 non-null float64
# state_house_district          765 non-null float64
# lat                           2116 non-null float64
# long                          2116 non-null float64
# dtypes: datetime64[ns](1), float64(5), object(9)
# memory usage: 264.5+ KB

# %%
installs_clean.drop(["fed_congressional_district", "state_senate_district", "state_house_district"], axis = 1, inplace = True)

# %%
installs_clean[installs_clean['utility'].isnull()]
# Out:
#              sea_install_id original_db    zip   fips      town    state  \
# 27           southface_SF24   Southface  30318  13121   Atlanta  Georgia
# 28           southface_SF25   Southface  30318  13121   Atlanta  Georgia
# 30           southface_SF33   Southface  30240  13285  LaGrange  Georgia
# 32           southface_SF20   Southface  30064  13067  Marietta  Georgia
# 33           southface_SF96   Southface  31774  13155    Ocilla  Georgia
# ...                     ...         ...    ...    ...       ...      ...
# 2134  southface_RS17-1-0003   Southface  30339  13067   Atlanta  Georgia
# 2135        southface_CS113   Southface  30306  13121   Atlanta  Georgia
# 2136         southface_AS10   Southface  30268  13077  Palmetto  Georgia
# 2137        southface_SF161   Southface  30810  13125    Gibson  Georgia
# 2138       southface_AES118   Southface  30017  13135   Grayson  Georgia
#
#           system_type           sector install_date utility        lat  \
# 27     Solar Electric  Non-Residential   1996-01-01     NaN  33.775772
# 28    Solar Hot Water  Non-Residential   1996-01-01     NaN  33.775772
# 30     Solar Electric  Non-Residential   1999-02-01     NaN  33.000525
# 32     Solar Electric      Residential   2003-01-01     NaN  33.934810
# 33     Solar Electric  Non-Residential   2005-08-18     NaN  31.581931
# ...               ...              ...          ...     ...        ...
# 2134   Solar Electric  Non-Residential   2017-08-30     NaN  33.880656
# 2135   Solar Electric      Residential   2017-08-30     NaN  33.778986
# 2136   Solar Electric      Residential   2017-09-01     NaN  33.498070
# 2137   Solar Electric          Utility   2017-09-13     NaN  33.210600
# 2138   Solar Electric      Residential   2017-02-28     NaN  33.891688
#
#            long
# 27   -84.402532
# 28   -84.402532
# 30   -85.056206
# 32   -84.640828
# 33   -83.240312
# ...         ...
# 2134 -84.470292
# 2135 -84.354015
# 2136 -84.718732
# 2137 -82.602739
# 2138 -83.964515
#
# [1515 rows x 12 columns]

# %%
utilities_needed = installs_clean.copy()

# %%
utilities_needed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2116 entries, 0 to 2138
# Data columns (total 12 columns):
# sea_install_id    2116 non-null object
# original_db       2116 non-null object
# zip               2116 non-null object
# fips              2116 non-null object
# town              2116 non-null object
# state             2116 non-null object
# system_type       2116 non-null object
# sector            2116 non-null object
# install_date      2116 non-null datetime64[ns]
# utility           601 non-null object
# lat               2116 non-null float64
# long              2116 non-null float64
# dtypes: datetime64[ns](1), float64(2), object(9)
# memory usage: 214.9+ KB

# %%
utilities_needed.drop(["sea_install_id", "original_db","fips","town","state","system_type","sector","install_date","lat","long"], axis = 1, inplace = True)

# %%
utilities_needed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2116 entries, 0 to 2138
# Data columns (total 2 columns):
# zip        2116 non-null object
# utility    601 non-null object
# dtypes: object(2)
# memory usage: 49.6+ KB

# %%
utilities_needed = utilities_needed[utilities_needed['utility'].isnull()]

# %%
utilities_needed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1515 entries, 27 to 2138
# Data columns (total 2 columns):
# zip        1515 non-null object
# utility    0 non-null object
# dtypes: object(2)
# memory usage: 35.5+ KB

# %%
utilities_needed.to_csv('utilities_needed.csv', encoding='utf-8', index=False)

# %%
utils_identified = pd.read_csv('utils_identified.csv', encoding='utf-8')
utils_identified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 2 columns):
# zip        360 non-null int64
# utility    360 non-null object
# dtypes: int64(1), object(1)
# memory usage: 5.8+ KB

# %%
utils_identified["zip"] = utils_identified['zip'].astype(str)
utils_identified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 2 columns):
# zip        360 non-null object
# utility    360 non-null object
# dtypes: object(2)
# memory usage: 5.8+ KB

# %%
installs_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2116 entries, 0 to 2138
# Data columns (total 12 columns):
# sea_install_id    2116 non-null object
# original_db       2116 non-null object
# zip               2116 non-null object
# fips              2116 non-null object
# town              2116 non-null object
# state             2116 non-null object
# system_type       2116 non-null object
# sector            2116 non-null object
# install_date      2116 non-null datetime64[ns]
# utility           601 non-null object
# lat               2116 non-null float64
# long              2116 non-null float64
# dtypes: datetime64[ns](1), float64(2), object(9)
# memory usage: 214.9+ KB

# %%
utils_identified_merge = pd.merge(installs_clean, utils_identified, on = 'zip', how = 'left')

# %%
utils_identified_merge.sample(5)
# Out:
#        sea_install_id original_db    zip   fips            town    state  \
# 1164   southface_OG18   Southface  30071  13135        Norcross  Georgia
# 866    southface_M280   Southface  30269  13113  Peachtree City  Georgia
# 63      southface_S56   Southface  31405  13051        Savannah  Georgia
# 342    southface_S104   Southface  30606  13059          Athens  Georgia
# 1565  southface_M1036   Southface  30607  13059          Athens  Georgia
#
#           system_type           sector install_date              utility_x  \
# 1164   Solar Electric  Non-Residential   2011-12-28  Georgia Power Company
# 866    Solar Electric  Non-Residential   2011-02-14                    NaN
# 63    Solar Hot Water      Residential   2008-01-01  Georgia Power Company
# 342    Solar Electric  Non-Residential   2009-10-05                    NaN
# 1565   Solar Electric      Residential   2013-06-17                    NaN
#
#             lat       long utility_y
# 1164  33.936297 -84.234006       NaN
# 866   33.367106 -84.575252       NaN
# 63    32.049878 -81.101236       NaN
# 342   33.963472 -83.414115       NaN
# 1565  33.992773 -83.486875       NaN

# %%
utils_identified_merge[utils_identified_merge['utility_x'].isnull()]
# Out:
#         sea_install_id original_db    zip   fips      town    state  \
# 31      southface_SF24   Southface  30318  13121   Atlanta  Georgia
# 32      southface_SF25   Southface  30318  13121   Atlanta  Georgia
# 33      southface_SF33   Southface  30240  13285  LaGrange  Georgia
# 34      southface_SF20   Southface  30064  13067  Marietta  Georgia
# 35      southface_SF96   Southface  31774  13155    Ocilla  Georgia
# ...                ...         ...    ...    ...       ...      ...
# 2470   southface_SF161   Southface  30810  13125    Gibson  Georgia
# 2471  southface_AES118   Southface  30017  13135   Grayson  Georgia
# 2472  southface_AES118   Southface  30017  13135   Grayson  Georgia
# 2473  southface_AES118   Southface  30017  13135   Grayson  Georgia
# 2474  southface_AES118   Southface  30017  13135   Grayson  Georgia
#
#           system_type           sector install_date utility_x        lat  \
# 31     Solar Electric  Non-Residential   1996-01-01       NaN  33.775772
# 32    Solar Hot Water  Non-Residential   1996-01-01       NaN  33.775772
# 33     Solar Electric  Non-Residential   1999-02-01       NaN  33.000525
# 34     Solar Electric      Residential   2003-01-01       NaN  33.934810
# 35     Solar Electric  Non-Residential   2005-08-18       NaN  31.581931
# ...               ...              ...          ...       ...        ...
# 2470   Solar Electric          Utility   2017-09-13       NaN  33.210600
# 2471   Solar Electric      Residential   2017-02-28       NaN  33.891688
# 2472   Solar Electric      Residential   2017-02-28       NaN  33.891688
# 2473   Solar Electric      Residential   2017-02-28       NaN  33.891688
# 2474   Solar Electric      Residential   2017-02-28       NaN  33.891688
#
#            long                            utility_y
# 31   -84.402532                                  NaN
# 32   -84.402532                                  NaN
# 33   -85.056206                                  NaN
# 34   -84.640828                                  NaN
# 35   -83.240312                                  NaN
# ...         ...                                  ...
# 2470 -82.602739          Washington Elec Member Corp
# 2471 -83.964515         City of Lawrenceville - (GA)
# 2472 -83.964515                     Georgia Power Co
# 2473 -83.964515  Jackson Electric Member Corp - (GA)
# 2474 -83.964515          Walton Electric Member Corp
#
# [1733 rows x 13 columns]

# %%
utils_identified_merge.utility_x.fillna(utils_identified_merge.utility_y, inplace=True)
del utils_identified_merge['utility_y']
utils_identified_merge.head(4)
# Out:
#   sea_install_id original_db    zip   fips         town    state  \
# 0  southface_S53   Southface  31408  13051  Garden City  Georgia
# 1  southface_S55   Southface  30601  13059       Athens  Georgia
# 2  southface_S59   Southface  30030  13089      Decatur  Georgia
# 3  southface_S52   Southface  30005  13121   Alpharetta  Georgia
#
#        system_type       sector install_date              utility_x  \
# 0  Solar Hot Water  Residential   2008-01-01  Georgia Power Company
# 1  Solar Hot Water  Residential   2008-01-01  Georgia Power Company
# 2  Solar Hot Water  Residential   2008-01-01  Georgia Power Company
# 3  Solar Hot Water  Residential   2008-01-01             Sawnee EMC
#
#          lat       long
# 0  32.119290 -81.151748
# 1  33.976445 -83.368683
# 2  33.767515 -84.308954
# 3  34.070288 -84.202196

# %%
utils_identified_merge["utility_x"].fillna("Unknown", inplace = True)

# %%
utils_identified_merge.head(25)
# Out:
#     sea_install_id original_db    zip   fips           town    state  \
# 0    southface_S53   Southface  31408  13051    Garden City  Georgia
# 1    southface_S55   Southface  30601  13059         Athens  Georgia
# 2    southface_S59   Southface  30030  13089        Decatur  Georgia
# 3    southface_S52   Southface  30005  13121     Alpharetta  Georgia
# 4    southface_S49   Southface  30281  13151    Stockbridge  Georgia
# 5    southface_S54   Southface  30549  13157      Jefferson  Georgia
# 6    southface_S54   Southface  30549  13157      Jefferson  Georgia
# 7    southface_S64   Southface  30549  13157      Jefferson  Georgia
# 8    southface_S64   Southface  30549  13157      Jefferson  Georgia
# 9    southface_S58   Southface  30650  13211        Madison  Georgia
# 10   southface_S65   Southface  30650  13211        Madison  Georgia
# 11   southface_S50   Southface  30677  13219   Watkinsville  Georgia
# 12   southface_S51   Southface  30621  13219         Bishop  Georgia
merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2475 entries, 0 to 2474
# Data columns (total 12 columns):
# sea_install_id    2475 non-null object
# original_db       2475 non-null object
# zip               2475 non-null object
# fips              2475 non-null object
# town              2475 non-null object
# state             2475 non-null object
# system_type       2475 non-null object
# sector            2475 non-null object
# install_date      2475 non-null datetime64[ns]
# utility_x         2475 non-null object
# lat               2475 non-null float64
# long              2475 non-null float64
# dtypes: datetime64[ns](1), float64(2), object(9)
# memory usage: 251.4+ KB

# %%
utils_identified_merge['sea_install_id'].duplicated().sum()
# Out:
# 365

# %%
utils_identified_merge['sea_install_id'].drop_duplicates(keep=False,inplace=True)

# %%
utils_identified_merge['sea_install_id'].duplicated().sum()
# Out:
# 0

# %%
utils_identified_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2475 entries, 0 to 2474
# Data columns (total 12 columns):
# sea_install_id    2475 non-null object
# original_db       2475 non-null object
# zip               2475 non-null object
# fips              2475 non-null object
# town              2475 non-null object
# state             2475 non-null object
# system_type       2475 non-null object
# sector            2475 non-null object
# install_date      2475 non-null datetime64[ns]
# utility_x         2475 non-null object
# lat               2475 non-null float64
# long              2475 non-null float64
# dtypes: datetime64[ns](1), float64(2), object(9)
# memory usage: 246.9+ KB

# %%
utils_identified_merge.sample(45)
# Out:
#            sea_install_id original_db    zip   fips            town    state  \
# 1645       southface_HS48   Southface  31068  13193      Oglethorpe  Georgia
# 1996       southface_IS10   Southface  31815  13259        Richland  Georgia
# 153         southface_S13   Southface  30281  13151     Stockbridge  Georgia
# 65          southface_S15   Southface  30607  13059          Athens  Georgia
# 1845  southface_GPC-10779   Southface  30909  13245         Augusta  Georgia
# 1690       southface_HS33   Southface  39826  13273        Bronwood  Georgia
# 2070       southface_CS28   Southface  30721  13313          Dalton  Georgia
# 225         southface_SF8   Southface  30601  13059          Athens  Georgia
# 1704      southface_SF130   Southface  30477  13163          Wadley  Georgia
# 892        southface_M290   Southface  31778  13275            Pavo  Georgia
# 1463       southface_SF22   Southface  31407  13051  Port Wentworth  Georgia
# 268        southface_S289   Southface  30809  13073           Evans  Georgia
# 813        southface_M258   Southface  30185  13045           White  Georgia
# 2381  southface_GPC-23284   Southface  31021  13175          Dublin  Georgia
# 2462      southface_CS118   Southface  30030  13089         Decatur  Georgia
# 2030      southface_HS128   Southface  31404  13051        Savannah  Georgia
# 1995       southface_IS10   Southface  31815  13259        Richland  Georgia
# 264        southface_S325   Southface  30033  13089         Decatur  Georgia
# 790        southface_M249   Southface  30666  13157         Statham  Georgia
# 1862      southface_SSM23   Southface  31763  13177        Leesburg  Georgia
# 1262       southface_M463   Southface  30906  13245         Augusta  Georgia
# 2120  southface_GPC-24711   Southface  31642  13003         Pearson  Georgia
# 798        southface_M251   Southface  30680  13013          Winder  Georgia
# 471        southface_S243   Southface  30076  13121         Roswell  Georgia
# 1882       southface_HS71   Southface  31092  13093          Vienna  Georgia
# 35         southface_SF96   Southface  31774  13155          Ocilla  Georgia
# 2412       southface_SA18   Southface  31061  13009   Milledgeville  Georgia
# 332   Solar Hot Water      Residential   2009-10-02
# 256   Solar Hot Water      Residential   2009-07-15
# 241   Solar Hot Water      Residential   2009-07-01
# 1161   Solar Electric  Non-Residential   2011-12-28
#
#                               utility_x        lat       long
# 1645              Georgia Power Company  32.281278 -84.063277
# 1996        Sumter Electric Member Corp  32.067511 -84.714017
# 153                             Unknown  33.542441 -84.261681
# 65                              Unknown  33.991432 -83.493784
# 1845                            Unknown  33.468797 -82.080681
# 1690                            Unknown  31.821586 -84.382792
# 2070                            Unknown  34.741520 -84.961889
# 225                             Unknown  33.958566 -83.369814
# 1704     Jefferson Electric Member Corp  32.883144 -82.408748
# 892   Colquitt Electric Membership Corp  30.981116 -83.756554
# 1463                   Georgia Power Co  32.176930 -81.172693
# 268               Georgia Power Company  33.584213 -82.198272
# 813         GreyStone Power Corporation  33.540485 -84.934954
# 2381                            Unknown  32.519251 -82.923794
# 2462                            Unknown  33.778211 -84.289100
# 2030                            Unknown  32.061821 -81.032970
# 1995                   Georgia Power Co  32.067511 -84.714017
# 264               Georgia Power Company  33.818314 -84.298007
# 790         Walton Electric Member Corp  33.999043 -83.529695
# 1862                            Unknown  31.636615 -84.274185
# 1262     Jefferson Electric Member Corp  33.336034 -81.966003
# 2120              Georgia Power Company  31.191851 -82.795247
# 798                             Unknown  33.993767 -83.709646
# 471                             Unknown  34.027356 -84.320103
# 1882                            Unknown  32.087670 -83.779692
# 35                              Unknown  31.581931 -83.240312
# 2412                            Unknown  33.040323 -83.245866
# 1168                            Unknown  32.194655 -81.633654
# 963                      Washington EMC  33.269828 -82.707248
# 472                             Unknown  32.839300 -83.636801
# 746                             Unknown  33.854078 -84.500706
# 1912                            Unknown  31.767623 -84.423704
# 2036                            Unknown  32.013095 -81.106927
# 1236              Georgia Power Company  33.601864 -84.315664
# 1465     Amicalola Electric Member Corp  34.328057 -84.710657
# 1507                            Unknown  34.409451 -84.011280
# 1871                            Unknown  34.567742 -84.982077
# 383                            Cobb EMC  33.949681 -84.727988
# 1537                            Unknown  33.164230 -83.279361
# 1623     Little Ocmulgee El Member Corp  31.626616 -82.887444
# 1432                   Georgia Power Co  33.325887 -82.018219
# 332                             Unknown  33.497556 -84.414593
# 256               Georgia Power Company  32.341956 -81.358719
# 241               Georgia Power Company  33.835393 -84.626914
# 1161     Amicalola Electric Member Corp  34.214799 -84.646722

# %%
utils_identified_merge['utility'] = utils_identified_merge['utility_x']

# %%
utils_identified_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2475 entries, 0 to 2474
# Data columns (total 13 columns):
# sea_install_id    2475 non-null object
# original_db       2475 non-null object
# zip               2475 non-null object
# fips              2475 non-null object
# town              2475 non-null object
# state             2475 non-null object
# system_type       2475 non-null object
# sector            2475 non-null object
# install_date      2475 non-null datetime64[ns]
# utility_x         2475 non-null object
# lat               2475 non-null float64
# long              2475 non-null float64
# utility           2475 non-null object
# dtypes: datetime64[ns](1), float64(2), object(10)
# memory usage: 270.7+ KB

# %%
utils_identified_merge.drop(["utility_x"], axis = 1, inplace = True)

# %%
installs_clean.to_csv('.csv', encoding='utf-8', index=False)
