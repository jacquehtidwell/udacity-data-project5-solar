# %% [markdown]
# # Utility Query

# %%
import requests
import numpy as np
import pandas as pd
import os
import io

import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import cm as cm

import seaborn as sns 
import datetime
from datetime import datetime

# %%
util_rates = pd.read_csv('clean_data/util_rates_clean.csv', encoding='utf-8')
util_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
# sea_rate_id     2000 non-null object
# year            2000 non-null object
# zip             2000 non-null int64
# utility_id      2000 non-null object
# service_type    2000 non-null object
# comm_rate       2000 non-null float64
# ind_rate        2000 non-null float64
# res_rate        2000 non-null float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 125.1+ KB

# %%
utils = pd.read_csv('clean_data/util_clean.csv', encoding='utf-8')
utils.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 3 columns):
# utility_id    74 non-null object
# name          74 non-null object
# ownership     74 non-null object
# dtypes: object(3)
# memory usage: 1.8+ KB

# %%
utils_combined = pd.merge(util_rates, utils, on = 'utility_id', how = 'left')

# %%
utils_combined.sample(5)
# Out:
#                  sea_rate_id                 year    zip   utility_id  \
# 1064  sea-util-44-rate-31629  2005-06-01 13:33:00  31629  sea-util-44
# 1480  sea-util-52-rate-30802  2005-06-01 13:33:00  30802  sea-util-52
# 478   sea-util-44-rate-31513  2005-06-01 13:33:00  31513  sea-util-44
# 1528  sea-util-54-rate-31079  2005-06-01 13:33:00  31079  sea-util-54
# 790   sea-util-44-rate-30420  2005-06-01 13:33:00  30420  sea-util-44
#
#      service_type  comm_rate  ind_rate  res_rate  \
# 1064      Bundled   0.095572  0.054794  0.121499
# 1480      Bundled   0.123904  0.092472  0.124166
# 478       Bundled   0.095572  0.054794  0.121499
# 1528      Bundled   0.126814  0.145127  0.119049
# 790       Bundled   0.095572  0.054794  0.121499
#
#                                 name       ownership
# 1064                Georgia Power Co  Investor Owned
# 1480  Jefferson Electric Member Corp     Cooperative
# 478                 Georgia Power Co  Investor Owned
# 1528   Middle Georgia El Member Corp     Cooperative
# 790                 Georgia Power Co  Investor Owned

# %%
utils_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
# sea_rate_id     2000 non-null object
# year            2000 non-null object
# zip             2000 non-null int64
# utility_id      2000 non-null object
# service_type    2000 non-null object
# comm_rate       2000 non-null float64
# ind_rate        2000 non-null float64
# res_rate        2000 non-null float64
# name            2000 non-null object
# ownership       2000 non-null object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 171.9+ KB

# %%
utils_needed = pd.read_csv('utilities_needed.csv', encoding='utf-8')
utils_needed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1521 entries, 0 to 1520
# Data columns (total 2 columns):
# zip        1521 non-null int64
# utility    0 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 23.8 KB

# %%
utils_identified = pd.merge(utils_needed, utils_combined, on = 'zip', how = 'left')

# %%
utils_identified.sample(5)
# Out:
#         zip  utility             sea_rate_id                 year  \
# 2178  30143      NaN  sea-util-44-rate-30143  2005-06-01 13:33:00
# 594   30257      NaN  sea-util-44-rate-30257  2005-06-01 13:33:00
# 2820  31419      NaN   sea-util-5-rate-31419  2005-06-01 13:33:00
# 40    31324      NaN  sea-util-33-rate-31324  2005-06-01 13:33:00
# 3523  30030      NaN  sea-util-44-rate-30030  2005-06-01 13:33:00
#
#        utility_id service_type  comm_rate  ind_rate  res_rate  \
# 2178  sea-util-44      Bundled   0.095572  0.054794  0.121499
# 594   sea-util-44      Bundled   0.095572  0.054794  0.121499
# 2820   sea-util-5      Bundled   0.112581  0.096920  0.125898
# 40    sea-util-33      Bundled   0.113631  0.081518  0.134683
# 3523  sea-util-44      Bundled   0.095572  0.054794  0.121499
#
#                                 name       ownership
# 2178                Georgia Power Co  Investor Owned
# 594                 Georgia Power Co  Investor Owned
# 2820  Canoochee Electric Member Corp     Cooperative
# 40      Coastal Electric Member Corp     Cooperative
# 3523                Georgia Power Co  Investor Owned

# %%
utils_identified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3766 entries, 0 to 3765
# Data columns (total 11 columns):
# zip             3766 non-null int64
# utility         0 non-null float64
# sea_rate_id     3762 non-null object
# year            3762 non-null object
# utility_id      3762 non-null object
# service_type    3762 non-null object
# comm_rate       3762 non-null float64
# ind_rate        3762 non-null float64
# res_rate        3762 non-null float64
# name            3762 non-null object
# ownership       3762 non-null object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 353.1+ KB

# %%
utils_identified['zip'].duplicated().sum()
# Out:
# 3356

# %%
utils_identified[utils_identified['zip'].duplicated()]
# Out:
#         zip  utility             sea_rate_id                 year  \
# 1     30318      NaN  sea-util-44-rate-30318  2005-06-01 13:33:00
# 3     30240      NaN  sea-util-23-rate-30240  2005-06-01 13:33:00
# 4     30240      NaN  sea-util-39-rate-30240  2005-06-01 13:33:00
# 5     30240      NaN  sea-util-44-rate-30240  2005-06-01 13:33:00
# 7     30064      NaN  sea-util-34-rate-30064  2005-06-01 13:33:00
# 8     30064      NaN  sea-util-44-rate-30064  2005-06-01 13:33:00
# 10    31774      NaN  sea-util-44-rate-31774  2005-06-01 13:33:00
# 11    31774      NaN  sea-util-50-rate-31774  2005-06-01 13:33:00
# 13    30290      NaN  sea-util-44-rate-30290  2005-06-01 13:33:00
# 14    30290      NaN  sea-util-46-rate-30290  2005-06-01 13:33:00
# 16    30677      NaN  sea-util-51-rate-30677  2005-06-01 13:33:00
# 17    30677      NaN  sea-util-73-rate-30677  2005-06-01 13:33:00
# 20    30094      NaN  sea-util-66-rate-30094  2005-06-01 13:33:00
# 22    30141      NaN  sea-util-44-rate-30141  2005-06-01 13:33:00
# 23    30141      NaN  sea-util-46-rate-30141  2005-06-01 13:33:00
# 25    30548      NaN  sea-util-51-rate-30548  2005-06-01 13:33:00
# 28    30286      NaN  sea-util-44-rate-30286  2005-06-01 13:33:00
# 29    30286      NaN  sea-util-72-rate-30286  2005-06-01 13:33:00
# 31    30116      NaN  sea-util-44-rate-30116  2005-06-01 13:33:00
# 32    30116      NaN  sea-util-46-rate-30116  2005-06-01 13:33:00
# 33    30305      NaN  sea-util-44-rate-30305  2005-06-01 13:33:00
# 36    30075      NaN  sea-util-34-rate-30075  2005-06-01 13:33:00
# 37    30075      NaN  sea-util-44-rate-30075  2005-06-01 13:33:00
# 38    30075      NaN  sea-util-64-rate-30075  2005-06-01 13:33:00
# 40    31324      NaN  sea-util-33-rate-31324  2005-06-01 13:33:00
# 41    31324      NaN  sea-util-44-rate-31324  2005-06-01 13:33:00
# 43    30434      NaN  sea-util-52-rate-30434  2005-06-01 13:33:00
# 44    30434      NaN  sea-util-61-rate-30434  2005-06-01 13:33:00
# 45    30434      NaN  sea-util-74-rate-30434  2005-06-01 13:33:00
# 47    31082      NaN  sea-util-59-rate-31082  2005-06-01 13:33:00
# ...     ...      ...                     ...                  ...
# 43            Jefferson Electric Member Corp     Cooperative
# 44             Planters Electric Member Corp     Cooperative
# 45               Washington Elec Member Corp     Cooperative
# 47               Oconee Electric Member Corp     Cooperative
# ...                                      ...             ...
# 3734                        Georgia Power Co  Investor Owned
# 3735                        Georgia Power Co  Investor Owned
# 3736                        Georgia Power Co  Investor Owned
# 3737           Coweta-Fayette El Member Corp     Cooperative
# 3738                        Georgia Power Co  Investor Owned
# 3739             GreyStone Power Corporation     Cooperative
# 3741          Jefferson Electric Member Corp     Cooperative
# 3742             Washington Elec Member Corp     Cooperative
# 3744                        Georgia Power Co  Investor Owned
# 3745     Jackson Electric Member Corp - (GA)     Cooperative
# 3746             Walton Electric Member Corp     Cooperative
# 3747           Cobb Electric Membership Corp     Cooperative
# 3748                        Georgia Power Co  Investor Owned
# 3749  Sawnee Electric Membership Corporation     Cooperative
# 3750                        Georgia Power Co  Investor Owned
# 3751     Jackson Electric Member Corp - (GA)     Cooperative
# 3752          Rayle Electric Membership Corp     Cooperative
# 3753             Walton Electric Member Corp     Cooperative
# 3754                        Georgia Power Co  Investor Owned
# 3755          Snapping Shoals El Member Corp     Cooperative
# 3756             Walton Electric Member Corp     Cooperative
# 3757                        Georgia Power Co  Investor Owned
# 3758          Snapping Shoals El Member Corp     Cooperative
# 3759             Walton Electric Member Corp     Cooperative
# 3760                        Georgia Power Co  Investor Owned
# 3761          Snapping Shoals El Member Corp     Cooperative
# 3762             Walton Electric Member Corp     Cooperative
# 3763                        Georgia Power Co  Investor Owned
# 3764      Habersham Electric Membership Corp     Cooperative
# 3765               Hart Electric Member Corp     Cooperative
#
# [3356 rows x 11 columns]

# %%
utils_identified.drop_duplicates(keep=False,inplace=True)

# %%
utils_identified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 358 entries, 19 to 3746
# Data columns (total 11 columns):
# zip             358 non-null int64
# utility         0 non-null float64
# sea_rate_id     354 non-null object
# year            354 non-null object
# utility_id      354 non-null object
# service_type    354 non-null object
# comm_rate       354 non-null float64
# ind_rate        354 non-null float64
# res_rate        354 non-null float64
# name            354 non-null object
# ownership       354 non-null object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 33.6+ KB

# %%
utils_identified.drop(["utility","sea_rate_id","year","utility_id","service_type","comm_rate","ind_rate","res_rate","ownership"], axis = 1, inplace = True)

# %%
utils_identified.isnull().sum()
# Out:
# zip     0
# name    4
# dtype: int64

# %%
utils_identified[utils_identified['name'].isnull()]
# Out:
#         zip name
# 99    32021  NaN
# 932   31350  NaN
# 2186  30155  NaN
# 2683  31504  NaN

# %%
utils_identified = utils_identified.dropna()

# %%
utils_identified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 354 entries, 19 to 3746
# Data columns (total 2 columns):
# zip     354 non-null int64
# name    354 non-null object
# dtypes: int64(1), object(1)
# memory usage: 8.3+ KB

# %%
utils_identified.duplicated().sum()
# Out:
# 0

# %%
utils_identified['utility'] = utils_identified['name']

# %%
utils_identified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 354 entries, 19 to 3746
# Data columns (total 3 columns):
# zip        354 non-null int64
# name       354 non-null object
# utility    354 non-null object
# dtypes: int64(1), object(2)
# memory usage: 11.1+ KB

# %%
utils_identified.drop(["name"], axis = 1, inplace = True)

# %%
utils_identified.to_csv('utils_identified.csv', encoding='utf-8', index=False)
